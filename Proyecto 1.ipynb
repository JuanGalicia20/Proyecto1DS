# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
deptos = [
    "El Progreso",
    "Alta Verapaz",
    "Baja Verapaz",
    "Chimaltenango",
    "Chiquimula",
    "Peten",
    "Quiche",
    "Escuintla",
    "Guatemala",
    "Huehuetenango",
    "Izabal",
    "Jalapa",
    "Jutiapa",
    "Quetzaltenango",
    "Retalhuleu",
    "Sacatepequez",
    "San Marcos",
    "Santa Rosa",
    "Solola",
    "Suchitepequez",
    "Totonicapan",
    "Zacapa"
]

# %%
df = pd.read_excel('Ciudad Capital.xlsx', skiprows=1)
print("Ciudad Capital:", len(df))

for dep in deptos:
    df2 = pd.read_excel(dep + '.xlsx', skiprows=1)
    print(dep + ":", len(df2))
    df = df.append(df2, ignore_index=True)

print(len(df))
df.dropna(subset = ['DEPARTAMENTO'], inplace=True)
# Out:
# Ciudad Capital: 1538
# El Progreso: 124
# Alta Verapaz: 350
# Baja Verapaz: 122
# Chimaltenango: 351
# Chiquimula: 174
# Peten: 381
# Quiche: 244
# Escuintla: 601
# Guatemala: 1434
# Huehuetenango: 497
# Izabal: 360
# Jalapa: 151
# Jutiapa: 322
# Quetzaltenango: 478
# Retalhuleu: 313
# Sacatepequez: 312
# San Marcos: 559
# Santa Rosa: 157
# Solola: 142
# Suchitepequez: 379
# Totonicapan: 92
# Zacapa: 97
# 9178

# %%
m = len(df)
m
# Out:
# 9136

# %%
df.isna().sum() / m
# Out:
# CODIGO             0.000000
# DISTRITO           0.022877
# DEPARTAMENTO       0.000000
# MUNICIPIO          0.000000
# ESTABLECIMIENTO    0.000000
# DIRECCION          0.005582
# TELEFONO           0.059873
# SUPERVISOR         0.022986
# DIRECTOR           0.148424
# NIVEL              0.000000
# SECTOR             0.000000
# AREA               0.000000
# STATUS             0.000000
# MODALIDAD          0.000000
# JORNADA            0.000000
# PLAN               0.000000
# DEPARTAMENTAL      0.000000
# dtype: float64

# %%
df.isna().any(axis=1).sum() / m
# Out:
# 0.17075306479859895

# %%
df[df.duplicated(['DEPARTAMENTO', 'MUNICIPIO', 'ESTABLECIMIENTO', 'DIRECCION', 'JORNADA'], keep=False)]
# Out:
#              CODIGO DISTRITO    DEPARTAMENTO  MUNICIPIO  \
# 16    00-01-0197-46   01-403  CIUDAD CAPITAL     ZONA 1
# 31    00-01-0218-46   01-403  CIUDAD CAPITAL     ZONA 1
# 74    00-01-0280-46   01-305  CIUDAD CAPITAL     ZONA 1
# 91    00-01-0318-46   01-317  CIUDAD CAPITAL     ZONA 1
# 92    00-01-0322-46   01-403  CIUDAD CAPITAL     ZONA 1
# ...             ...      ...             ...        ...
# 9123  19-01-1012-46   19-019          ZACAPA     ZACAPA
# 9145  19-05-0028-46   19-010          ZACAPA  TECULUTAN
# 9150  19-05-0047-46   19-010          ZACAPA  TECULUTAN
# 9169  19-09-0034-46   19-021          ZACAPA   LA UNION
# 9170  19-09-0037-46   19-021          ZACAPA   LA UNION
#
#                                         ESTABLECIMIENTO  \
# 16           LICEO TECNOLOGICO GUATEMALA DE LA ASUNCION
# 31           LICEO TECNOLOGICO GUATEMALA DE LA ASUNCION
# 74                    COLEGIO TECNICO COMERCIAL NAHUALA
# 91                         LICEO HISPANOAMERICANO NO. 2
# 92                         LICEO HISPANOAMERICANO NO. 2
# ...                                                 ...
# 9123  CENTRO EDUCATIVO JUVENIL CATOLICO NUESTRA SEÑO...
# 9145                                 GETHSEMANE COLLEGE
# 9150                                 GETHSEMANE COLLEGE
# 9169                     LICEO PARTICULAR MIXTO "JIREH"
# 9170                     LICEO PARTICULAR MIXTO "JIREH"
#
#                                      DIRECCION    TELEFONO  \
# 16                              3A. CALLE 7-64    54452951
# 31                              3A. CALLE 7-64    54452951
# 74                           3A. AVENIDA 13-23    22329664
# 91                              2A. CALLE 7-11    22205687
# 92                              2A. CALLE 7-11    22205687
# ...                                        ...         ...
# 9123                   12 CALLE A 14-03 ZONA 1  79410382.0
# 9145  CAMINO QUE CONDUCE HACIA LA ALDEA LA PAZ  41503049.0
# 9150  CAMINO QUE CONDUCE HACIA LA ALDEA LA PAZ  41503049.0
# 9169                              BARRIO NUEVO  79418369.0
# 9170                              BARRIO NUEVO  79418369.0
#
#                                SUPERVISOR  \
# 16       CARLOS HUMBERTO GONZALEZ DE LEON
# 31       CARLOS HUMBERTO GONZALEZ DE LEON
# 74               ISIS IRAZEMA CANEL PALMA
# 91        MARIANO DOMINGO ESTRADA TELETOR
# 92       CARLOS HUMBERTO GONZALEZ DE LEON
# ...                                   ...
# 9123          HUGO WILFREDO VARGAS CHACON
# 9145              OSCAR OVIDIO FRANCO PAZ
# 9150              OSCAR OVIDIO FRANCO PAZ
# 9169  BERTA ALICIA LEIVA CORDON DE GARCIA
# 9170  BERTA ALICIA LEIVA CORDON DE GARCIA
#
#                                         DIRECTOR          NIVEL   SECTOR  \
# 16             ELUBIA ANAYTE SIGUENZA MONTERROSO  DIVERSIFICADO  PRIVADO
# 31             ELUBIA ANAYTE SIGUENZA MONTERROSO  DIVERSIFICADO  PRIVADO
# 74                  OVIDIO LISANDRA OROZCO LOPEZ  DIVERSIFICADO  PRIVADO
# 91                      MARIA ISABEL POLANCO PAZ  DIVERSIFICADO  PRIVADO
# 92                      MARIA ISABEL POLANCO PAZ  DIVERSIFICADO  PRIVADO
# ...                                          ...            ...      ...
# 9123                 FIDIAS ROBERTO MONROY LEMUS  DIVERSIFICADO  PRIVADO
# 9145  KATHY JOHANNA MORALES MANCILLA DE SALGUERO  DIVERSIFICADO  PRIVADO
# 9150  KATHY JOHANNA MORALES MANCILLA DE SALGUERO  DIVERSIFICADO  PRIVADO
# 9169         ANA MARÍA CUELLAR GUERRA DE RAMÍREZ  DIVERSIFICADO  PRIVADO
# 9170         ANA MARÍA CUELLAR GUERRA DE RAMÍREZ  DIVERSIFICADO  PRIVADO
#
#         AREA                 STATUS   MODALIDAD   JORNADA             PLAN  \
# 16    URBANA                ABIERTA  MONOLINGUE     DOBLE    FIN DE SEMANA
# 31    URBANA                ABIERTA  MONOLINGUE     DOBLE    FIN DE SEMANA
# 74    URBANA  CERRADA TEMPORALMENTE  MONOLINGUE  MATUTINA  DIARIO(REGULAR)
# 91    URBANA                ABIERTA  MONOLINGUE  MATUTINA  DIARIO(REGULAR)
# 92    URBANA                ABIERTA  MONOLINGUE     DOBLE    FIN DE SEMANA
# ...      ...                    ...         ...       ...              ...
# 9123  URBANA                ABIERTA  MONOLINGUE  MATUTINA  DIARIO(REGULAR)
# 9145  URBANA  CERRADA TEMPORALMENTE  MONOLINGUE     DOBLE  DIARIO(REGULAR)
# 9150  URBANA  CERRADA TEMPORALMENTE  MONOLINGUE     DOBLE  DIARIO(REGULAR)
# 9169  URBANA                ABIERTA  MONOLINGUE     DOBLE    FIN DE SEMANA
# 9170  URBANA                ABIERTA  MONOLINGUE     DOBLE  DIARIO(REGULAR)
#
#         DEPARTAMENTAL
# 16    GUATEMALA NORTE
# 31    GUATEMALA NORTE
# 74    GUATEMALA NORTE
# 91    GUATEMALA NORTE
# 92    GUATEMALA NORTE
# ...               ...
# 9123           ZACAPA
# 9145           ZACAPA
# 9150           ZACAPA
# 9169           ZACAPA
# 9170           ZACAPA
#
# [1203 rows x 17 columns]

# %%
df[df.duplicated(['CODIGO'], keep=False)]
# Out:
# Empty DataFrame
# Columns: [CODIGO, DISTRITO, DEPARTAMENTO, MUNICIPIO, ESTABLECIMIENTO, DIRECCION, TELEFONO, SUPERVISOR, DIRECTOR, NIVEL, SECTOR, AREA, STATUS, MODALIDAD, JORNADA, PLAN, DEPARTAMENTAL]
# Index: []
